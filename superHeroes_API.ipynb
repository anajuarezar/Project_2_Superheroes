# %%
# Dependencies
import requests
import json
import pandas as pd

# Heroes API Key
from config import API_KEY

# %%
base_url = "https://superheroapi.com/api/"

# %%
heroes = []

for h in range(1,10):
    url = base_url + API_KEY + "/" + str(h)

    response = requests.get(url)#.json()
    #content = json.dumps(response, indent = 4, sort_keys=True)
    

    #hero = 
    heroes.append(response.json())

# %%
Heroes_df = pd.DataFrame(heroes)
# Out:
#   response id           name  \
# 0  success  1         A-Bomb
# 1  success  2     Abe Sapien
# 2  success  3       Abin Sur
# 3  success  4    Abomination
# 4  success  5        Abraxas
# 5  success  6  Absorbing Man
# 6  success  7    Adam Monroe
# 7  success  8   Adam Strange
# 8  success  9       Agent 13
#
#                                           powerstats  \
# 0  {'intelligence': '38', 'strength': '100', 'spe...
# 1  {'intelligence': '88', 'strength': '28', 'spee...
# 2  {'intelligence': '50', 'strength': '90', 'spee...
# 3  {'intelligence': '63', 'strength': '80', 'spee...
# 4  {'intelligence': '88', 'strength': '63', 'spee...
# 5  {'intelligence': '38', 'strength': '80', 'spee...
# 6  {'intelligence': '63', 'strength': '10', 'spee...
# 7  {'intelligence': '69', 'strength': '10', 'spee...
# 8  {'intelligence': 'null', 'strength': '46', 'sp...
#
#                                            biography  \
# 0  {'full-name': 'Richard Milhouse Jones', 'alter...
# ...

# %%
# Out:
# 0    {'full-name': 'Richard Milhouse Jones', 'alter...
# Name: biography, dtype: object

# %%
heroes_json
# Out:
# '{"columns":["response","id","name","powerstats","biography","appearance","work","connections","image"],"index":[0,1,2,3,4,5,6,7,8],"data":[["success","1","A-Bomb",{"intelligence":"38","strength":"100","speed":"17","durability":"80","power":"24","combat":"64"},{"full-name":"Richard Milhouse Jones","alter-egos":"No alter egos found.","aliases":["Rick Jones"],"place-of-birth":"Scarsdale, Arizona","first-appearance":"Hulk Vol 2 #2 (April, 2008) (as A-Bomb)","publisher":"Marvel Comics","alignment":"good"},{"gender":"Male","race":"Human","height":["6\'8","203 cm"],"weight":["980 lb","441 kg"],"eye-color":"Yellow","hair-color":"No Hair"},{"occupation":"Musician, adventurer, author; formerly talk show host","base":"-"},{"group-affiliation":"Hulk Family; Excelsior (sponsor), Avengers (honorary member); formerly partner of the Hulk, Captain America and Captain Marvel; Teen Brigade; ally of Rom","relatives":"Marlo Chandler-Jones (wife); Polly (aunt); Mrs. Chandler (mother-in-law); Keith Chandl
# ...
